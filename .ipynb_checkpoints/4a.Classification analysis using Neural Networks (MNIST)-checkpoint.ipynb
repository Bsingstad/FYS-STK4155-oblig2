# %%
import tensorflow as tf
# %load_ext autoreload
# %autoreload
from Scripts import get_data
from Scripts import NeuralNetwork
from Scripts import plot
from Scripts import metrics
import matplotlib.pyplot as plt
import numpy as np
from tqdm import trange
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
import seaborn as sns
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
X_train, y_train, _, _, X_test, y_test = get_data.load_dataset(flatten=True)

# %%
# %matplotlib inline
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.title("Label: %i"%y_train[i])
    plt.imshow(X_train[i].reshape([28,28]),cmap='gray');

# %%
ohe = OneHotEncoder()
ohe.fit(y_train.reshape(-1, 1))
# Out:
# OneHotEncoder()

# %%
y_train_ohe = ohe.transform(y_train.reshape(-1, 1)).toarray()

# %%
y_val_ohe = ohe.transform(y_val.reshape(-1, 1)).toarray()

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=2)
epochs = [5,10,15]
batch_size = 100
#eta = 0.001
lmbd = [0.00001,0.001,0.1]
#n_hidden_neurons = [10,30,50]
#learning_rate = [0.1,0.01,0.001,0.0001,0.00001,0.000001]


for eta in learning_rate:
    for train_index, test_index in kf.split(X_train):
        #print("TRAIN:", train_index, "TEST:", test_index)
        X_train_, X_val_ = X_train[train_index], X_train[test_index]
        y_train_, y_val_ = y_train_ohe[train_index], y_train_ohe[test_index]

        dnn = NeuralNetwork.NN_clf(X_train, y_train_ohe,eta=eta, lmbd=lmbd, epochs=epochs, batch_size=batch_size,
                            n_hidden_neurons=n_hidden_neurons, n_categories=y_train_ohe.shape[1])
        dnn.train(X_val, y_val_ohe,ohe.transform)
        val_predict = dnn.predict(X_val_)
        print(metrics.compute_accuracy(y_val_.argmax(axis=1).reshape(y_val_.argmax(axis=1).shape[0],1),val_predict.reshape(val_predict.shape[0],1)))
# Out:
# 0.1399
# 0.099
# 0.0983
# 0.09659806803863923
# 0.099
# 0.0967
# 0.0991
# 0.09611807763844724
# 0.1096
# 0.1445
# 0.0967
# 0.09888395535821433
# 0.8877
# 0.8913
# 0.8879
# 0.878922421551569
# 0.8876
# 0.8829
# 0.8903
# 0.8800023999520009
# 0.8838
# 0.8795
# 0.8968
# 0.8858154326173047
# 0.6503
# 0.7969
# 0.8615
# 0.8451430971380572
# 0.6143
# 0.7761
# 0.8531
# 0.8287034259314814
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-f8c53e6b808b> in <module>
#      17         dnn = NeuralNetwork.NN_clf(X_train, y_train_ohe,eta=eta, lmbd=lmbd, epochs=epochs, batch_size=batch_size,
#      18                             n_hidden_neurons=n_hidden_neurons, n_categories=y_train_ohe.shape[1])
# ---> 19         dnn.train(X_val, y_val_ohe,ohe.transform)
#      20         val_predict = dnn.predict(X_val_)
#      21         print(metrics.compute_accuracy(y_val_.argmax(axis=1).reshape(y_val_.argmax(axis=1).shape[0],1),val_predict.reshape(val_predict.shape[0],1)))
#
# ~\OneDrive\Documents\Github\FYS-STK4155-oblig2\Scripts\NeuralNetwork.py in train(self, X_val, y_val, transformer)
#     305                 self.Y_data = self.Y_data_full[chosen_datapoints]
#     306
# --> 307                 self.feed_forward()
#     308                 self.backpropagation()
#     309             pred_val = self.predict(X_val)
#
# ~\OneDrive\Documents\Github\FYS-STK4155-oblig2\Scripts\NeuralNetwork.py in feed_forward(self)
#     223             return A
#     224         # feed-forward for training
# --> 225         self.z_h = np.matmul(self.X_data, self.hidden_weights) + self.hidden_bias
#     226         self.a_h = sigmoid(self.z_h)
#     227
#
# KeyboardInterrupt:

# %%
print(metrics.compute_accuracy(y_test.reshape(y_test.shape[0],1),test_predict.reshape(test_predict.shape[0],1)))

# %%
conf_matrix = plot.compute_modified_confusion_matrix_nonorm(y_test_ohe, y_pred_ohe)

# %%
plt.figure(figsize = (20,20))
sns.set(font_scale=1.4)#for label size
sns.heatmap(conf_matrix, cmap="rocket_r", annot=True,annot_kws={"size": 20}, fmt=".2f", cbar=False)
plt.title("Predict MNIST data using own Neural Network", fontsize = 40, color= "black")
plt.xlabel("y predicted",fontsize=30, color= "black")
plt.ylabel("y true",fontsize = 30, color= "black")
plt.yticks(fontsize=30, rotation=0, color= "black")
plt.xticks(fontsize=30, rotation=0, color= "black")
plt.savefig("Results/MNIST_confMatrix_ownNN.png",dpi=100)
plt.show()
